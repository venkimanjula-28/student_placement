# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as pyplot
data=pd.read_csv("../Data/Sample.csv")
data.head()
data.info()
data.describe()
sns.countplot(x="Placement(Y/N)?", data=data)
plt.show()
sns.scatterplot(x="Cgpa", y="Communication level",data=data)
plt.show()
